# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-96/Bengali_data_analysi/blob/main/Code_to_access_WB_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !pip install wbgapi

# %%
import wbgapi as wb

# %% [markdown]
# # Show Available Database in the WB

# %%
print(wb.source.info())  # Should show available databases
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2025-07-01
# 3     Worldwide Governance Indicators                                       WGI              3  2024-11-05
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2025-02-26
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2024-06-25
# ...

# %% [markdown]
# # To access Specific Data we need a indicators

# %%
# Switch to Gender Statistics (GDS - ID 14)
wb.db = 14 # or wb.db = 'GDS'

# Search for GDP-related indicators
gdp_indicators = wb.series.info(q='GDP per capita')
print(gdp_indicators)
# Out:
# id              value
# --------------  ----------------------------------
# NY.GDP.PCAP.CD  GDP per capita (Current US$)
# NY.GDP.PCAP.KD  GDP per capita (constant 2015 US$)
#                 2 elements

# %%
# Search for GDP-related indicators
Gender_Statistics = wb.series.info(q='Gender Statistics')
print(Gender_Statistics)

# %% [markdown]
# # To find the short form of the country in the dataset

# %%
import wbgapi as wb
import pandas as pd

# List all economies/countries
countries = wb.economy.list()

# Show first 10
df_countries = pd.DataFrame(countries)

print("Columns of the dataset:\n", df_countries.columns)

print("\n\n----------------Find using Country Name-----------------------\n")

# Search the short form of country Bangladesh
print(df_countries.loc[df_countries["value"] == "Bangladesh", ["id", "value"]])    # Search using Value which is country Name

print("\n\n---------------Show all info. related to BGD ------------------------\n")

df_countries[df_countries["capitalCity"] == "Dhaka"]     # Search using Capitalcity
# Out:
# Columns of the dataset:
#  Index(['id', 'value', 'aggregate', 'longitude', 'latitude', 'region',
#        'adminregion', 'lendingType', 'incomeLevel', 'capitalCity'],
#       dtype='object')
#
#
# ----------------Find using Country Name-----------------------
#
#      id       value
# 20  BGD  Bangladesh
#
#
# ---------------Show all info. related to BGD ------------------------
#      id       value  aggregate  longitude  latitude region adminregion  \
# 20  BGD  Bangladesh      False    90.4113   23.7055    SAS         SAS
#
#    lendingType incomeLevel capitalCity
# 20         IDX         LMC       Dhaka
